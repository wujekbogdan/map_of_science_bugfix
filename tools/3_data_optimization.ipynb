# %% [markdown]
# # Data optimization

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Reading data

# %%
with open('data/basic_data.jsonl', "r") as f:
    data = "[" + ",".join(f.readlines()) + "]"
data = json.loads(data)
df = pd.DataFrame(data)

# %%
df
# Out:
#        cluster_id                                       key_concepts  \
# 0           84872  [historical performance practice, Don Juan, Ba...
# 1           72062  [Early Modern Art, John Singleton Copley, Scot...
# 2           62380  [Malay gamelan music, folk music, Music Theory...
# 3           65319  [Rite of Spring, Indonesian piano music, piano...
# 4           72024  [Mediterranean Marine Caves, Marine Caves, mar...
# ...           ...                                                ...
# 85638        6047  [Tissue Engineering, cell culture, Cell Cultur...
# 85639         129  [graphene oxide, Reduced Graphene, Functionali...
# 85640       41756  [OLED display, crystalline oxide semiconductor...
# 85641         213  [chemical vapor deposition, CVD graphene films...
# 85642         151  [anode materials, silicon anode, lithium-ion b...
#
#        num_recent_articles   cluster_category  growth_rating         x  \
# 0                      228         humanities          15.43  -90.2114
# 1                      239         humanities           3.22  -76.1376
# 2                      283         humanities          33.33 -160.4460
# 3                      242         humanities           3.11  -78.1228
# 4                      104            biology          74.75  -45.6533
# ...                    ...                ...            ...       ...
# 85638                  686  materials science          52.10  320.7678
# 85639                 1982  materials science          33.59  230.4844
# 85640                  376  materials science          44.26  168.4628
# 85641                 1651  materials science          19.63   98.1491
# 85642                 3359  materials science          62.57  252.1484
#
#               y
# 0      -71.3960
# 1      -37.2588
# 2       20.6144
# 3      -68.1877
# 4      178.6693
# ...         ...
# 85638  181.4553
# 85639  350.5407
# 85640  392.2027
# 85641  416.9048
# 85642  375.5727
#
# [85643 rows x 7 columns]

# %% [markdown]
# ## Counting Clusters

# %%
cats = sorted(list(set(data_point["cluster_category"] for data_point in data)))

# %%
def cluster_name_to_index(cluster_name):
    match cluster_name:
        case 'biology': return 0
        case 'chemistry': return 1
        case 'computer science': return 2
        case 'earth science': return 3
        case 'engineering': return 4
        case 'humanities': return 5
        case 'materials science': return 6
        case 'mathematics': return 7
        case 'medicine': return 8
        case 'physics': return 9
        case 'social science': return 10
        case _: return -1

def cluster_index_to_name(cluster_index):
    match cluster_index:
        case 0: return 'biology'
        case 1: return 'chemistry'
        case 2: return 'computer science'
        case 3: return 'earth science'
        case 4: return 'engineering'
        case 5: return 'humanities'
        case 6: return 'materials science'
        case 7: return 'mathematics'
        case 8: return 'medicine'
        case 9: return 'physics'
        case 10: return 'social science'
        case _: return ''

# %% [markdown]
# ### Counting Key concepts

# %%
df.loc[df["key_concepts"].isna(),"key_concepts"] = "[]"

# %%
keys = sorted(list(set([key for group in df["key_concepts"] for key in group])))

# %%
keys_dict = {key: i for i, key in enumerate(keys)}
keys_dict
# Out:
# {'12-20210031': 0,
#  '1790-1920': 1,
#  '19-9 levels': 2,
#  '1‒3 November': 3,
#  '2012-13 French pill': 4,
#  '2012-2013 Central African': 5,
#  '2018-2020 Period': 6,
#  '25-6981': 7,
#  '2950:1974 Brown coal': 8,
#  '4,4′': 9,
#  'A-Ring Substituted Anthraquinone': 10,
#  'A-Site Cation Ordering': 11,
#  'A-Site Columnar-Ordered Quadruple': 12,
#  'A-induced Liver Injury': 13,
#  'A-induced autoimmune hepatitis': 14,
#  'A-kinase anchor protein': 15,
#  'A-kinase anchoring protein': 16,
#  'A-kinase interacting protein': 17,
#  'A-level geology': 18,
#  'A-level scenic spots': 19,
#  'A-numerical radius': 20,
#  'A-sandwich radome': 21,
#  'A-separable modules': 22,
#  'A-share listed companies': 23,
#  'A-site non-stoichiometry': 24,
#  'A-site spinel': 25,
#  'A-type PACs': 26,
#  'A-type carbonate': 27,
#  'A-type cost factors': 28,
#  'A-type lamins': 29,
#  'A.chinensis adults': 30,
#  'AAA': 31,
#  'AAA Annual Meeting': 32,
#  'AAA formation': 33,
#  'AAA growth': 34,
#  'AAA growth rate': 35,
#  'AAA patients': 36,
#  'AAA repair': 37,
#  'AAA rupture': 38,
#  'AAC': 39,
#  'AAC concrete production': 40,
#  'AAC intervention': 41,
#  'AAC research': 42,
#  'AAC system': 43,
#  'AAC system performance': 44,
#  'AAC systems': 45,
#  'AACE III patients': 46,
#  'AACMM measurement model': 47,
#  'AACP Leadership Development': 48,
#  'AACR reflects': 49,
#  'AACW': 50,
#  'AAD': 51,
#  'AADC deficiency': 52,
#  'AADL architecture model': 53,
#  'AADL models': 54,
#  'AADT data': 55,
#  'AAGGG repeat expansion': 56,
#  'AAI DNA adduct': 57,
#  'AAI exposure': 58,
#  'AAL systems': 59,
#  'AAL technologies': 60,
#  'AAL-speaking African American': 61,
#  'AAMR': 62,
#  'AAN control scheme': 63,
#  'AANAT': 64,
#  'AAO templates': 65,
#  'AAP': 66,
#  'AAP AOM guidelines': 67,
#  'AAPC': 68,
#  'AAPI women': 69,
#  'AAPMA': 70,
#  'AAR': 71,
#  'AARF': 72,
#  'AAS': 73,
#  'AAS side effects': 74,
#  'AAS users': 75,
#  'AAS users reported': 76,
#  'AASHTO LRFD Bridge': 77,
#  'AASI': 78,
#  'AASM Scoring Manual': 79,
#  'AAT': 80,
#  'AAT augmentation therapy': 81,
#  'AAT deficiency': 82,
#  'AAT protein levels': 83,
#  'AATD': 84,
#  'AATD lung disease': 85,
#  'AATD patients': 86,
#  'AATF expression': 87,
#  'AATF knockdown': 88,
#  'AAV': 89,
#  'AAV Gene': 90,
#  'AAV Vectors': 91,
#  'AAV capsid': 92,
#  'AAV gene': 93,
#  'AAV gene therapy': 94,
#  'AAV patients': 95,
#  'AAV retinal gene': 96,
#  'AAV vector amount': 97,
#  'AAV vectors': 98,
#  'AAs': 99,
#  'ABA': 100,
#  'ABA Alleviates Uptake': 101,
#  'ABA biosynthesis genes': 102,
#  'ABA concentration': 103,
#  'ABA content': 104,
#  'ABA levels': 105,
#  'ABA model': 106,
#  'ABA receptor': 107,
#  'ABA receptors': 108,
#  'ABA service delivery': 109,
#  'ABA signaling': 110,
#  'ABA treatment': 111,
#  'ABAC policy mining': 112,
#  'ABAD': 113,
#  'ABAMECTIN PESTICIDE PRODUCTS': 114,
#  'ABBA': 115,
#  'ABC Inventory Classification': 116,
#  'ABC Proteins': 117,
#  'ABC Transporter Genes': 118,
#  'ABC Transporters': 119,
#  'ABC algorithm study': 120,
#  'ABC analysis': 121,
#  'ABC dry powder': 122,
#  'ABC gene': 123,
#  'ABC gene expression': 124,
#  'ABC genes': 125,
#  'ABC intervention': 126,
#  'ABC method': 127,
#  'ABC pathway': 128,
#  'ABC transporter genes': 129,
#  'ABC transporter inhibitors': 130,
#  'ABC transporters': 131,
#  'ABCD analysis framework': 132,
#  'ABD': 133,
#  'ABDUCTIVE REASONING': 134,
#  'ABE': 135,
#  'ABE fermentation': 136,
#  'ABE production compared': 137,
#  'ABEEM PFF method': 138,
#  'ABEEM polarizable force': 139,
#  'ABES Engineering College': 140,
#  'ABFM': 141,
#  'ABG': 142,
#  'ABH antigens': 143,
#  'ABH beam': 144,
#  'ABH beam structure': 145,
#  'ABH blood groups': 146,
#  'ABH effect': 147,
#  'ABI': 148,
#  'ABIKO iron': 149,
#  'ABILITY IN ELEMENTARY': 150,
#  'ABL': 151,
#  'ABL kinase inhibitor': 152,
#  'ABM': 153,
#  'ABM agents': 154,
#  'ABM construction research': 155,
#  'ABM model development': 156,
#  'ABM simulation framework': 157,
#  'ABM state': 158,
#  'ABNT NBR': 159,
#  'ABO Blood Group': 160,
#  'ABO Compatibility Important': 161,
#  'ABO HDFN': 162,
#  'ABO Hemolytic Disease': 163,
#  'ABO Non-Identical Platelet': 164,
#  'ABO blood group': 165,
#  'ABO blood groups': 166,
#  'ABO gene': 167,
#  'ABO haemolytic disease': 168,
#  'ABO incompatibility': 169,
#  'ABO type blood': 170,
#  'ABO-Incompatible Renal Transplantation': 171,
#  'ABO-incompatible kidney transplantation': 172,
#  'ABP': 173,
#  'ABP blood biomarkers': 174,
#  'ABPA complicating asthma': 175,
#  'ABPA patients': 176,
#  'ABPM': 177,
#  'ABPMR Certification Exams': 178,
#  'ABR': 179,
#  'ABR detection methods': 180,
#  'ABR response thresholds': 181,
#  'ABR signal': 182,
#  'ABR threshold': 183,
#  'ABR waveforms': 184,
#  'ABRASION RESISTANCE': 185,
#  'ABRF Research Groups.': 186,
#  'ABS': 187,
#  'ABS Nanocomposite Material': 188,
#  'ABS based composites': 189,
#  'ABS blends': 190,
#  'ABS group': 191,
#  'ABS matrix materials': 192,
#  'ABS plastic': 193,
#  'ABS polymer blend': 194,
#  'ABSTRACT Background Inpatient': 195,
#  'ABSTRACT Background Physics': 196,
#  'ABSTRACT Bradypus variegatus': 197,
#  'ABSTRACT Chionanthus pubescens': 198,
#  'ABSTRACT Classical developmentalism': 199,
#  'ABSTRACT Elyonurus muticus': 200,
#  'ABSTRACT English Medium': 201,
#  'ABSTRACT Introduction Leishmaniasis': 202,
#  'ABSTRACT Malassezia species': 203,
#  'ABSTRACT Mitochondrial Complex': 204,
#  'ABSTRACT Nontypeable Haemophilus': 205,
#  'ABSTRACT OBJECTIVE': 206,
#  'ABSTRACT Objective': 207,
#  'ABSTRACT Shigella flexneri': 208,
#  'ABT': 209,
#  'ABTS radical scavenging': 210,
#  'ABVD': 211,
#  'ABZ suspension': 212,
#  'ABZ treatment': 213,
#  'AC-AC Buck Converter': 214,
#  'AC-Feasible Linear Model': 215,
#  'ACA': 216,
#  'ACA box snoRNAs': 217,
#  'ACA frequency': 218,
#  'ACA occlusion': 219,
#  'ACA territory infarction': 220,
#  'ACACIA SENEGAL': 221,
#  'ACADEMIC LEADERS': 222,
#  'ACADEMIC NOTES': 223,
#  'ACAN gene': 224,
#  'ACAN gene variants': 225,
#  'ACAP': 226,
#  'ACAT inhibitors': 227,
#  'ACB fractures': 228,
#  'ACB system': 229,
#  'ACBP family proteins': 230,
#  'ACBP gene family': 231,
#  'ACC': 232,
#  'ACC cell': 233,
#  'ACC glutamate levels': 234,
#  'ACC inhibitors': 235,
#  'ACC neurons': 236,
#  'ACC oxidase': 237,
#  'ACC patients': 238,
#  'ACCESS NETWORK ENGINEERING': 239,
#  'ACCESS TO CREDIT': 240,
#  'ACCOUNTING INFORMATION': 241,
#  'ACCOUNTING PRINCIPLES': 242,
#  'ACCUSATIVE CASE': 243,
#  'ACD': 244,
#  'ACD models': 245,
#  'ACDF': 246,
#  'ACDMPV lungs': 247,
#  'ACDO devices': 248,
#  'ACE C-domain': 249,
#  'ACE Inhibitors': 250,
#  'ACE Inhibitory Peptides': 251,
#  'ACE activity': 252,
#  'ACE angioedema cases': 253,
#  'ACE gene': 254,
#  'ACE gene polymorphism': 255,
#  'ACE gene variants': 256,
#  'ACE inhibitor-induced angioedema': 257,
#  'ACE inhibitors': 258,
#  'ACE phenotyping': 259,
#  'ACE tax system': 260,
#  'ACEH BEEF CATTLE': 261,
#  'ACEI': 262,
#  'ACETIC ACID': 263,
#  'ACETYLCHOLINESTERASE INHIBITORY ACTIVITY': 264,
#  'ACEXO': 265,
#  'ACEi treatment': 266,
#  'ACF': 267,
#  'ACF TGR': 268,
#  'ACGME Resident Survey': 269,
#  'ACH': 270,
#  'ACHD patients': 271,
#  'ACHIEVEMENT GOALS': 272,
#  'ACHM patient retinal': 273,
#  'ACI intravenous thrombolysis': 274,
#  'ACI rats': 275,
#  'ACID CONJUGATES': 276,
#  'ACID HYDROGEL SCAFFOLD': 277,
#  'ACJ': 278,
#  'ACL Reconstruction': 279,
#  'ACL graft': 280,
#  'ACL graft fixation': 281,
#  'ACL grafts': 282,
#  'ACL injuries': 283,
#  'ACL injury': 284,
#  'ACL injury prevention': 285,
#  'ACL injury risk': 286,
#  'ACL mucoid degeneration': 287,
#  'ACL reconstruction': 288,
#  'ACL reconstruction graft': 289,
#  'ACL reconstruction infection': 290,
#  'ACL reconstruction model': 291,
#  'ACL reconstruction patients': 292,
#  'ACL repair': 293,
#  'ACL revision surgery': 294,
#  'ACL rupture': 295,
#  'ACL tears': 296,
#  'ACL tissue': 297,
#  'ACL tissue engineering': 298,
#  'ACLF patients': 299,
#  'ACM': 300,
#  'ACM International Conference': 301,
#  'ACM MobiCom': 302,
#  'ACM SIGMOBILE conference': 303,
#  'ACM Southeast Conference': 304,
#  'ACM patients': 305,
#  'ACME electron EDM': 306,
#  'ACN group': 307,
#  'ACO genes': 308,
#  'ACOG Committee Opinion': 309,
#  'ACOUSTIC CHARACTERISTICS': 310,
#  'ACOUSTIC EMISSION': 311,
#  'ACOUSTIC SCREENS': 312,
#  'ACP': 313,
#  'ACP coating films': 314,
#  'ACPA': 315,
#  'ACPM DFB laser': 316,
#  'ACPs': 317,
#  'ACQUITY UPLC BEH': 318,
#  'ACR': 319,
#  'ACR classification criteria': 320,
#  'ACR criteria': 321,
#  'ACR exposure': 322,
#  'ACRF showed': 323,
#  'ACRL Framework': 324,
#  'ACS': 325,
#  'ACS Infect': 326,
#  'ACS Omega': 327,
#  'ACS exposure': 328,
#  'ACS for higher': 329,
#  'ACS treatment showed': 330,
#  'ACSA cement composites': 331,
#  'ACT interventions': 332,
#  'ACTAR TPC detector': 333,
#  'ACTB mRNA': 334,
#  'ACTB mRNA translation': 335,
#  'ACTB mutations': 336,
#  'ACTERIA prizes': 337,
#  'ACTH': 338,
#  'ACTH Excess': 339,
#  'ACTH concentrations': 340,
#  'ACTH stimulation test': 341,
#  'ACTH syndrome EAS': 342,
#  'ACTH-dependent Cushing Syndrome': 343,
#  'ACTION RESEARCH TRAINING': 344,
#  'ACTIVATED CARBON': 345,
#  'ACTIVATED SLUDGE': 346,
#  'ACTIVE LEARNING TECHNIQUES': 347,
#  'ACTIVE NOISE CONTROL': 348,
#  'ACUTE LOW BACK': 349,
#  'ACV': 350,
#  'ACWR': 351,
#  'ACYCLIC SPORTS': 352,
#  'ACh': 353,
#  'ACh application': 354,
#  'ACh content': 355,
#  'ACh release': 356,
#  'AChA aneurysms': 357,
#  'AChE': 358,
#  'AChE active site': 359,
#  'AChE activity': 360,
#  'AChE and BuChE': 361,
#  'AChE expression': 362,
#  'AChE inhibitors': 363,
#  'AChR clustering': 364,
#  'ADA': 365,
#  'ADA Assay': 366,
#  'ADA Deficiency': 367,
#  'ADA Professional Practice': 368,
#  'ADA activity': 369,
#  'ADA enzyme': 370,
#  'ADA response': 371,
#  'ADA scientific council': 372,
#  'ADAM Additive Technologies': 373,
#  'ADAM SMITH': 374,
#  'ADAMTS Proteases': 375,
#  'ADAMTS family': 376,
#  'ADAMTS gene expression': 377,
#  'ADAPTIVE GENETIC ALGORITHM': 378,
#  'ADAPTIVE PROJECT MANAGEMENT': 379,
#  'ADB': 380,
#  'ADB system': 381,
#  'ADBB scale': 382,
#  'ADC': 383,
#  'ADC BIST techniques': 384,
#  'ADC Based': 385,
#  'ADC MIMO channel': 386,
#  'ADC Nonlinearity': 387,
#  'ADC Testing': 388,
#  'ADC Therapeutics': 389,
#  'ADC achieves': 390,
#  'ADC calibration scheme': 391,
#  'ADC development': 392,
#  'ADC drugs': 393,
#  'ADC group': 394,
#  'ADC histogram parameters': 395,
#  'ADC massive MIMO': 396,
#  'ADCC': 397,
#  'ADCP discharge measurements': 398,
#  'ADCs': 399,
#  'ADEM cases': 400,
#  'ADENOCARCINOMA ANAL': 401,
#  'ADF STEM Images': 402,
#  'ADG': 403,
#  'ADH activity': 404,
#  'ADH gene': 405,
#  'ADH isoenzymes': 406,
#  'ADHD': 407,
#  'ADHD EEG': 408,
#  'ADHD EEG signals': 409,
#  'ADHD Overlap': 410,
#  'ADHD Rating Scale': 411,
#  'ADHD Symptoms': 412,
#  'ADHD Teacher Training': 413,
#  'ADHD Therapies JACC': 414,
#  'ADHD candidate genes': 415,
#  'ADHD children': 416,
#  'ADHD clinical trials': 417,
#  'ADHD deficit': 418,
#  'ADHD diagnosis': 419,
#  'ADHD group': 420,
#  'ADHD groups': 421,
#  'ADHD medication': 422,
#  'ADHD medication prescriptions': 423,
#  'ADHD medication treatment': 424,
#  'ADHD patients': 425,
#  'ADHD polygenic risk': 426,
#  'ADHD rat model': 427,
#  'ADHD risk': 428,
#  'ADHD symptoms': 429,
#  'ADHD traits': 430,
#  'ADHD treatment': 431,
#  'ADHD 儿童症状与焦虑问题之间起中介作用，同时性别调节了 ADHD': 432,
#  'ADHD 儿童认知重评策略在 ADHD': 433,
#  'ADHM Sigma Model': 434,
#  'ADI': 435,
#  'ADI overlay measurement': 436,
#  'ADIANTUM CAPILLUS-VENERIS': 437,
#  'ADIDAS Brand': 438,
#  'ADITYA Upgrade tokamak': 439,
#  'ADITYA tokamak plasma': 440,
#  'ADK inhibition': 441,
#  'ADKAR CHANGE MODEL': 442,
#  'ADL': 443,
#  'ADL motor ability': 444,
#  'ADL task performance': 445,
#  'ADL test': 446,
#  'ADM Cells': 447,
#  'ADM expression': 448,
#  'ADM group': 449,
#  'ADM mass': 450,
#  'ADM receptor antagonist': 451,
#  'ADMA': 452,
#  'ADMA levels': 453,
#  'ADME Assay': 454,
#  'ADMET': 455,
#  'ADMET Prediction': 456,
#  'ADMINISTRATION DOMAIN MODEL': 457,
#  'ADMINISTRATION EDUCATION STUDY': 458,
#  'ADMM penalized decoding': 459,
#  'ADN Solid': 460,
#  'ADN Solid Propellants': 461,
#  'ADN based propellant': 462,
#  'ADN stimulation evoked': 463,
#  'ADNP gene mutation': 464,
#  'ADNP syndrome': 465,
#  'ADP': 466,
#  'ADP and AMP': 467,
#  'ADP-Glucose Pyrophosphorylase': 468,
#  'ADP-ribose': 469,
#  'ADP-ribosylation factor': 470,
#  'ADPKD kidney cysts': 471,
#  'ADR': 472,
#  'ADR cells': 473,
#  'ADR reporting': 474,
#  'ADRD diagnosis': 475,
#  'ADRENAL GLANDS': 476,
#  'ADRs': 477,
#  'ADS PubMed': 478,
#  'ADS patients': 479,
#  'ADS reactor core': 480,
#  'ADS-B system': 481,
#  'ADSC sheet': 482,
#  'ADSC-EXO': 483,
#  'ADSL deficiency': 484,
#  'ADSL gene': 485,
#  'ADSORPTION': 486,
#  'ADSORPTION ACTIVITY': 487,
#  'ADT': 488,
#  'ADULT EDUCATION': 489,
#  'ADULT EDUCATION PRACTICE': 490,
#  'ADULT LEARNING': 491,
#  'ADULT QUAILS': 492,
#  'ADUs': 493,
#  'ADVANCED MORPHOLOGICAL APPROACH': 494,
#  'ADVERTISEMENT RETURN': 495,
#  'AEB system': 496,
#  'AEB vehicle tests': 497,
#  'AEDs': 498,
#  'AEG patients': 499,
#  'AEI zeolite synthesis': 500,
#  'AEL erythroid blasts': 501,
#  'AEM': 502,
#  'AEN': 503,
#  'AEP': 504,
#  'AEPL treatment': 505,
#  'AERATED CONCRETE': 506,
#  'AERD patients': 507,
#  'AERMOD dispersion model': 508,
#  'AEROBIC AND ANAEROBIC': 509,
#  'AEROBIC DIGESTION PROCESS': 510,
#  'AEROBIC EXERCISE': 511,
#  'AERONET aerosol retrieval': 512,
#  'AEROSOL LAYERS': 513,
#  'AEROSOL LIDAR': 514,
#  'AEROSPACE INDUSTRY': 515,
#  'AES Encryption Algorithm': 516,
#  'AES Rijndael algorithm': 517,
#  'AES encryption algorithm': 518,
#  'AES participation': 519,
#  'AESA radar': 520,
#  'AESTHETICS': 521,
#  'AEV infection': 522,
#  'AEZ': 523,
#  'AF-PLL staining': 524,
#  'AFA steel': 525,
#  'AFAP Cyclic Executives': 526,
#  'AFAR': 527,
#  'AFB': 528,
#  'AFC': 529,
#  'AFD type methods': 530,
#  'AFE cases': 531,
#  'AFE phase boundary': 532,
#  'AFFECTING THIN FILM': 533,
#  'AFFIRMATIVE ACTION': 534,
#  'AFFIRMATIVE ACTION POLICIES': 535,
#  'AFI': 536,
#  'AFL induced TCM': 537,
#  'AFL patients': 538,
#  'AFLP patients': 539,
#  'AFM': 540,
#  'AFM Cantilevers': 541,
#  'AFM Kondo lattice': 542,
#  'AFM Measurements': 543,
#  'AFM Tip': 544,
#  'AFM cantilever force': 545,
#  'AFM cases': 546,
#  'AFM image': 547,
#  'AFM images': 548,
#  'AFM imaging': 549,
#  'AFM probe': 550,
#  'AFM tip': 551,
#  'AFM tips': 552,
#  'AFO': 553,
#  'AFO ankle stiffness': 554,
#  'AFP': 555,
#  'AFP expression': 556,
#  'AFP gene': 557,
#  'AFP negative HCC': 558,
#  'AFP promotes HCC': 559,
#  'AFR control system': 560,
#  'AFRICAN AMERICAN': 561,
#  'AFRICAN INDIGENOUS KNOWLEDGE': 562,
#  'AFRICAN MIDDLE AGES': 563,
#  'AFT': 564,
#  'AFU levels': 565,
#  'AFib amyloidosis': 566,
#  'AGA activity': 567,
#  'AGA protein': 568,
#  'AGAT': 569,
#  'AGATA tracking array': 570,
#  'AGB SiC grains': 571,
#  'AGB estimation model': 572,
#  'AGB stars': 573,
#  'AGC Loops': 574,
#  'AGD': 575,
#  'AGD measurements': 576,
#  'AGE accumulation': 577,
#  'AGE formation': 578,
#  'AGEING PROCESS': 579,
#  'AGEs formation': 580,
#  'AGHD patients': 581,
#  'AGI': 582,
#  'AGI risk research': 583,
#  'AGI system NARS': 584,
#  'AGI system design': 585,
#  'AGILE Gamma-Ray Telescope': 586,
#  'AGILE MCAL GRB': 587,
#  'AGILE MDAO system': 588,
#  'AGILE data center': 589,
#  'AGILE space Mission': 590,
#  'AGIQ': 591,
#  'AGM belief revision': 592,
#  'AGM revision functions': 593,
#  'AGN': 594,
#  'AGN Feedback': 595,
#  'AGN Spectroscopic Survey': 596,
#  'AGN feedback': 597,
#  'AGN host galaxies': 598,
#  'AGN jets': 599,
#  'AGN light curves': 600,
#  'AGN optical light': 601,
#  'AGN polar dust': 602,
#  'AGN variability': 603,
#  'AGNIKARMA': 604,
#  'AGP levels': 605,
#  'AGRICULTURAL COOPERATIVES': 606,
#  'AGRICULTURAL DRAINAGE WATER': 607,
#  'AGRICULTURAL ENTERPRISES': 608,
#  'AGRICULTURAL FIELDS': 609,
#  'AGRICULTURAL GREEN DEVELOPMENT': 610,
#  'AGRICULTURAL LABOR PRODUCTIVITY': 611,
#  'AGRICULTURAL LAND CLEARING': 612,
#  'AGRICULTURAL MARKET': 613,
#  'AGRIMIN AND FISHMIN': 614,
#  'AGS': 615,
#  'AGS cell line': 616,
#  'AGS system': 617,
#  'AGSM': 618,
#  'AGT': 619,
#  'AGT Inhibitors': 620,
#  'AGT expression': 621,
#  'AGTF control system': 622,
#  'AGV Fault Diagnosis': 623,
#  'AGV Robot Based': 624,
#  'AGV Simulation System': 625,
#  'AGV path planning': 626,
#  'AGV scheduling': 627,
#  'AGV system': 628,
#  'AHA Clinical Practice': 629,
#  'AHA patients': 630,
#  'AHBA': 631,
#  'AHBAC': 632,
#  'AHC outbreaks': 633,
#  'AHCC supplementation': 634,
#  'AHCY deficiency': 635,
#  'AHCY gene': 636,
#  'AHDS': 637,
#  'AHEAD displays data': 638,
#  'AHEI': 639,
#  'AHF': 640,
#  'AHFP': 641,
#  'AHHC medical services': 642,
#  'AHI': 643,
#  'AHL family genes': 644,
#  'AHL gene family': 645,
#  'AHLs': 646,
#  'AHP': 647,
#  'AHP Method': 648,
#  'AHP method': 649,
#  'AHP method based': 650,
#  'AHP-TOPSIS Assessing Environmental': 651,
#  'AHR': 652,
#  'AHR activation': 653,
#  'AHR computational model': 654,
#  'AHR knockout mice': 655,
#  'AHR legislation': 656,
#  'AHR ligands': 657,
#  'AHR target genes': 658,
#  'AHS vector Culicoides': 659,
#  'AHSCT': 660,
#  'AHSP': 661,
#  'AHTO': 662,
#  'AI-aided Contract Authoring': 663,
#  'AI-generated scientific text': 664,
#  'AIAA High Lift': 665,
#  'AIBP': 666,
#  'AIC': 667,
#  'AIC waves': 668,
#  'AICA': 669,
#  'AICR Cancer Prevention': 670,
#  'AICV flow performance': 671,
#  'AID SERVICE QUALITY': 672,
#  'AID expression': 673,
#  'AID system': 674,
#  'AIDA Model': 675,
#  'AIDS Knowledge': 676,
#  'AIDS Memorial': 677,
#  'AIDS Patients': 678,
#  'AIDS RISK': 679,
#  'AIDS Research HIV': 680,
#  'AIDS cases': 681,
#  'AIDS cases aged': 682,
#  'AIDS crisis': 683,
#  'AIDS health education': 684,
#  'AIDS health literacy': 685,
#  'AIDS home-based care': 686,
#  'AIDS in Mali': 687,
#  'AIDS information system': 688,
#  'AIDS knowledge': 689,
#  'AIDS mortality': 690,
#  'AIDS pandemic': 691,
#  'AIDS patients': 692,
#  'AIDS policy': 693,
#  'AIDS prevention': 694,
#  'AIDS received ART': 695,
#  'AIDS risk': 696,
#  'AIDS risk perception': 697,
#  'AIDS virus transmission': 698,
#  'AIDS-associated Kaposi sarcoma': 699,
#  'AIE PSs': 700,
#  'AIE Zinc Complexes': 701,
#  'AIE exposure': 702,
#  'AIE luminogen': 703,
#  'AIE luminogens': 704,
#  'AIE materials': 705,
#  'AIE photosensitizers': 706,
#  'AIE polymers': 707,
#  'AIE rats': 708,
#  'AIED Opinion': 709,
#  'AIF': 710,
#  'AIF Education Scheme': 711,
#  'AIF expression': 712,
#  'AIF variant cells': 713,
#  'AIFV Codes': 714,
#  'AIG genes': 715,
#  'AIG patients': 716,
#  'AIGA': 717,
#  'AIH diagnosis': 718,
#  'AIH patients': 719,
#  'AIHA': 720,
#  'AIHA patients': 721,
#  'AII amacrine cells': 722,
#  'AIM expression levels': 723,
#  'AIM levels significantly': 724,
#  'AIN': 725,
#  'AIN pts': 726,
#  'AIOLOS': 727,
#  'AIP index': 728,
#  'AIP patients': 729,
#  'AIP type': 730,
#  'AIR TRANSPORTATION SYSTEM': 731,
#  'AIRBORNE LIDAR POINT': 732,
#  'AIRmax': 733,
#  'AIRmin mice': 734,
#  'AIS': 735,
#  'AIS channel protein': 736,
#  'AIS data': 737,
#  'AIS group': 738,
#  'AIS patients': 739,
#  'AIS receiver': 740,
#  'AISI': 741,
#  'AISI SAE': 742,
#  'AIT': 743,
#  'AITC concentration': 744,
#  'AITL patients': 745,
#  'AIUM Practice Parameter': 746,
#  'AIV infection': 747,
#  'AIV infection group': 748,
#  'AIVR burden': 749,
#  'AJCC Cancer Staging': 750,
#  'AJCC stage': 751,
#  'AJCC stage melanomas': 752,
#  'AJCC staging system': 753,
#  'AJE': 754,
#  'AJP': 755,
#  'AJR manuscript review': 756,
#  'AKARI NEP field': 757,
#  'AKARI North Ecliptic': 758,
#  'AKBA': 759,
#  'AKBIS Prob': 760,
#  'AKD sizing': 761,
#  'AKG': 762,
#  'AKG group': 763,
#  'AKG supplementation': 764,
#  'AKH peptide': 765,
#  'AKH receptor': 766,
#  'AKH signaling': 767,
#  'AKI': 768,
#  'AKI Biomarkers': 769,
#  'AKI biomarkers': 770,
#  'AKI developed AKI': 771,
#  'AKI grade': 772,
#  'AKI group': 773,
#  'AKI intervention groups': 774,
#  'AKI patients': 775,
#  'AKI requiring RRT': 776,
#  'AKI severity AKI': 777,
#  'AKI treatment': 778,
#  'AKP Turkey foreign': 779,
#  'AKP composite fibers': 780,
#  'AKP government': 781,
#  'AKR emissions': 782,
#  'AKT': 783,
#  'AKT Pathway': 784,
#  'AKT Signaling Pathway': 785,
#  'AKT inducing cancer': 786,
#  'AKT inhibitors': 787,
#  'AKT isoform expression': 788,
#  'AKT isoforms': 789,
#  'AKT signaling': 790,
#  'AKT signaling pathway': 791,
#  'AKU mice': 792,
#  'AKU patients': 793,
#  'ALA': 794,
#  'ALA Group': 795,
#  'ALA application': 796,
#  'ALA production': 797,
#  'ALA supplementation': 798,
#  'ALA treatment': 799,
#  'ALANS': 800,
#  'ALAS': 801,
#  'ALB gene': 802,
#  'ALB ratio': 803,
#  'ALB variants': 804,
#  'ALBA': 805,
#  'ALBA COUNTY': 806,
#  'ALBI grade': 807,
#  'ALCAM expression': 808,
#  'ALCAR': 809,
#  'ALCL cell lines': 810,
#  'ALCL cells': 811,
#  'ALCTS Electronic Resources': 812,
#  'ALD': 813,
#  'ALD BeO dielectric': 814,
#  'ALD FIB': 815,
#  'ALD ZnO films': 816,
#  'ALD deposited films': 817,
#  'ALD film growth': 818,
#  'ALD films': 819,
#  'ALD newborn screening': 820,
#  'ALD precursor': 821,
#  'ALD process': 822,
#  'ALD processes': 823,
#  'ALDFG': 824,
#  'ALDH gene superfamily': 825,
#  'ALDO': 826,
#  'ALDOA expression': 827,
#  'ALE approach': 828,
#  'ALE process': 829,
#  'ALFAXALONE': 830,
#  'ALFQ': 831,
#  'ALG': 832,
#  'ALGAE': 833,
#  'ALGORITHMIC DESCRIPTION': 834,
#  'ALGS patients': 835,
#  'ALI exosomes': 836,
#  'ALI induced': 837,
#  'ALI mice': 838,
#  'ALI model rats': 839,
#  'ALI rat model': 840,
#  'ALICE FIT detector': 841,
#  'ALICE experiment': 842,
#  'ALK': 843,
#  'ALK Resistance Mutations': 844,
#  'ALK TKIs': 845,
#  'ALK expression': 846,
#  'ALK fusion': 847,
#  'ALK inhibitors': 848,
#  'ALK mutations': 849,
#  'ALK tyrosine kinase': 850,
#  'ALK-positive anaplastic large': 851,
#  'ALLO': 852,
#  'ALLOY': 853,
#  'ALM': 854,
#  'ALMA': 855,
#  'ALMA High-frequency Long-baseline': 856,
#  'ALMA Spectroscopic Survey': 857,
#  'ALMA Three-millimeter Observations': 858,
#  'ALMM Based Learning': 859,
#  'ALN': 860,
#  'ALO': 861,
#  'ALOHA Based': 862,
#  'ALOS PALSAR': 863,
#  'ALP': 864,
#  'ALP Activity': 865,
#  'ALP activity': 866,
#  'ALP detection': 867,
#  'ALP genes': 868,
#  'ALP isoform elevation': 869,
#  'ALP levels': 870,
#  'ALP poisoned patients': 871,
#  'ALP production': 872,
#  'ALPL gene': 873,
#  'ALPS': 874,
#  'ALPS patients': 875,
#  'ALR expression': 876,
#  'ALS': 877,
#  'ALS Functional Rating': 878,
#  'ALS care': 879,
#  'ALS cell lines': 880,
#  'ALS clinical trials': 881,
#  'ALS data': 882,
#  'ALS gene': 883,
#  'ALS gene revealed': 884,
#  'ALS individuals': 885,
#  'ALS inhibitors': 886,
#  'ALS model': 887,
#  'ALS mouse model': 888,
#  'ALS patients': 889,
#  'ALS risk': 890,
#  'ALSN signal disturbances': 891,
#  'ALSN system': 892,
#  'ALSP': 893,
#  'ALT cancer cells': 894,
#  'ALT flap': 895,
#  'ALT flap perforators': 896,
#  'ALT level': 897,
#  'ALT levels': 898,
#  'ALT ratio': 899,
#  'ALT ratio increased': 900,
#  'ALTERNATIVE FUEL': 901,
#  'ALTERNATIVE VISCOMETER': 902,
#  'ALTP heat flux': 903,
#  'ALUMINUM ALLOY': 904,
#  'ALUMINUM HYDROXIDE DRIED': 905,
#  'ALV subgroup': 906,
#  'ALV-J infection': 907,
#  'ALVE insertion': 908,
#  'ALVT': 909,
#  'AMA': 910,
#  'AMACR deficiency': 911,
#  'AMB': 912,
#  'AMB system': 913,
#  'AMBA AHB Bus': 914,
#  'AMBER to GROMACS': 915,
#  'AMBIENT TEMPERATURE': 916,
#  'AMBN': 917,
#  'AMBTC Compressed Images': 918,
#  'AMC': 919,
#  'AMC Surface': 920,
#  'AMC groups': 921,
#  'AMC staining': 922,
#  'AMC training': 923,
#  'AMD': 924,
#  'AMD EPYC Rome': 925,
#  'AMD GPUs': 926,
#  'AMD Quantity': 927,
#  'AMD RPE EVs': 928,
#  'AMD diagnosis': 929,
#  'AMD eyes': 930,
#  'AMD patients': 931,
#  'AMD treatment': 932,
#  'AMDV infection': 933,
#  'AME': 934,
#  'AMERICAN STATE': 935,
#  'AMF': 936,
#  'AMF Inoculation': 937,
#  'AMF Rhizophagus irregularis': 938,
#  'AMF colonization': 939,
#  'AMF communities': 940,
#  'AMF community': 941,
#  'AMF diversity': 942,
#  'AMF improves plant': 943,
#  'AMF inoculation': 944,
#  'AMF root': 945,
#  'AMF root colonization': 946,
#  'AMF significantly increased': 947,
#  'AMF species': 948,
#  'AMF strains': 949,
#  'AMH concentration': 950,
#  'AMH levels': 951,
#  'AMH receptor type': 952,
#  'AMH serum levels': 953,
#  'AMI': 954,
#  'AMI patients': 955,
#  'AMICUS CURIAE': 956,
#  'AMINO ACID AMINOTRANSFERASE': 957,
#  'AMINO ACIDS PROFILE': 958,
#  'AMINOPHENOLS': 959,
#  'AMIS': 960,
#  'AML': 961,
#  'AML Directive': 962,
#  'AML MRD': 963,
#  'AML MRD testing': 964,
#  'AML cell': 965,
#  'AML cell lines': 966,
#  'AML cells': 967,
#  'AML cells including': 968,
#  'AML methylation subtypes': 969,
#  'AML patients': 970,
#  'AML single-pill combination': 971,
#  'AMM systolic thickening': 972,
#  'AMOG': 973,
#  'AMOLED Displays': 974,
#  'AMORPHOUS FILMS': 975,
#  'AMOT expression': 976,
#  'AMP': 977,
#  'AMP algorithms': 978,
#  'AMP binding site': 979,
#  'AMP deaminase': 980,
#  'AMP delivery systems': 981,
#  'AMP in human': 982,
#  'AMP levels': 983,
#  'AMP prediction': 984,
#  'AMP receptor protein': 985,
#  'AMP sequences': 986,
#  'AMP-PCW test': 987,
#  'AMP-activated protein kinase': 988,
#  'AMPA receptor': 989,
#  'AMPA receptor neurotransmission': 990,
#  'AMPA receptors': 991,
#  'AMPAR auxiliary subunits': 992,
#  'AMPAR trafficking': 993,
#  'AMPARs': 994,
#  'AMPK': 995,
#  'AMPK activates TFEB': 996,
#  'AMPK activation': 997,
#  'AMPK protein expression': 998,
#  'AMPK signaling': 999,
#  ...}

# %%
len(keys)
# Out:
# 274422

# %% [markdown]
# ## Optimization

# %%
X = df["x"].to_list()
Y = df["y"].to_list()
ID = df["cluster_id"].to_list()
SIZE = df["num_recent_articles"].to_list()
CATEGORY = [cluster_name_to_index(cat) for cat in df["cluster_category"].to_list()]
GROWTH = df["growth_rating"].to_list()

# %%
KEYS = []

for idx, group in enumerate(df["key_concepts"].to_list()):
    KEYS.append([keys_dict[key] for key in group])

# %% [markdown]
# ### TO CSV

# %%
pd.DataFrame({
    "cluster_id": ID,
    "x": X,
    "y": Y,
    "num_recent_articles": SIZE,
    "cluster_category": CATEGORY,
    "growth_rating": GROWTH,
    "key_concepts": KEYS
}).to_csv("data/processed0_data.csv", index=False)

# %%
pd.DataFrame({
    "cluster_id": ID,
    "x": X,
    "y": Y,
    "num_recent_articles": SIZE,
    "cluster_category": CATEGORY,
    "growth_rating": GROWTH,
    "key_concepts": KEYS
}).to_csv("data/processed0_data.tsv", index=False, sep="\t")

# %%
# !ls -la ./data
# Out:
# total 90044
# drwxrwxr-x 2 szymon szymon     4096 lip  5 18:46 .
# drwxrwxr-x 3 szymon szymon     4096 lip  5 18:49 ..
# -rw-r--r-- 1 szymon szymon 23155895 lip  5 09:33 basic_data_fixed.jsonl
# -rw-r--r-- 1 szymon szymon 23070251 lip  5 09:25 basic_data.jsonl
# -rw-rw-r-- 1 szymon szymon 27062067 lip  5 09:25 data_obj.json
# -rw-rw-r-- 1 szymon szymon  6582948 lip  5 18:57 processed0_data.csv
# -rw-rw-r-- 1 szymon szymon  6411666 lip  5 18:57 processed0_data.tsv
# -rw-rw-r-- 1 szymon szymon  5899376 lip  5 18:49 processed1_data.tsv

# %%
processed1 = open("data/processed0_data.tsv", "r").read()
processed1 = processed1 \
    .replace("[", "") \
    .replace("]", "") \
    .replace(" ", "")
open("data/processed1_data.tsv", "w").write(processed1)
# Out:
# 5899376

# %%
# !ls -la ./data
# Out:
# total 90044
# drwxrwxr-x 2 szymon szymon     4096 lip  5 18:46 .
# drwxrwxr-x 3 szymon szymon     4096 lip  5 18:49 ..
# -rw-r--r-- 1 szymon szymon 23155895 lip  5 09:33 basic_data_fixed.jsonl
# -rw-r--r-- 1 szymon szymon 23070251 lip  5 09:25 basic_data.jsonl
# -rw-rw-r-- 1 szymon szymon 27062067 lip  5 09:25 data_obj.json
# -rw-rw-r-- 1 szymon szymon  6582948 lip  5 18:57 processed0_data.csv
# -rw-rw-r-- 1 szymon szymon  6411666 lip  5 18:57 processed0_data.tsv
# -rw-rw-r-- 1 szymon szymon  5899376 lip  5 18:57 processed1_data.tsv

# %%
df_keys = pd.DataFrame({
    "index": [keys_dict[key] for key in keys],
    "key": keys,
})
df_keys.to_csv("data/processed0_keys.csv", index=False, sep="\t")

# %%
# !ls -la ./data
# Out:
# total 97428
# drwxrwxr-x 2 szymon szymon     4096 lip  5 18:59 .
# drwxrwxr-x 3 szymon szymon     4096 lip  5 18:49 ..
# -rw-r--r-- 1 szymon szymon 23155895 lip  5 09:33 basic_data_fixed.jsonl
# -rw-r--r-- 1 szymon szymon 23070251 lip  5 09:25 basic_data.jsonl
# -rw-rw-r-- 1 szymon szymon 27062067 lip  5 09:25 data_obj.json
# -rw-rw-r-- 1 szymon szymon  6582948 lip  5 18:57 processed0_data.csv
# -rw-rw-r-- 1 szymon szymon  6411666 lip  5 18:57 processed0_data.tsv
# -rw-rw-r-- 1 szymon szymon  7558356 lip  5 18:59 processed0_keys.csv
# -rw-rw-r-- 1 szymon szymon  5899376 lip  5 18:57 processed1_data.tsv

# %%
7558356 + 5899376
# Out:
# 13457732

# %%
df_cats = pd.DataFrame({
    "index": [cluster_name_to_index(cat) for cat in cats],
    "category": cats,
})
df_cats.to_csv("data/processed0_categories.csv", index=False, sep="\t")
